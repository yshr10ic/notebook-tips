# %% [markdown]
# # Google ColaboratoryでChainerCVのチュートリアルを実行してみる
#
# 今回実行するのは、ChainerCVのドキュメントにある[Object Detection Tutorial](https://chainercv.readthedocs.io/en/stable/tutorial/detection.html)を実行する。

# %%
# chainercvをインストール
# !pip install chainercv
# Out:
# ...
#     100% |████████████████████████████████| 245kB 7.6MB/s
# ...
#   Stored in directory: /root/.cache/pip/wheels/48/34/47/ace83b5217d8cd49bd017951c776588fd4a7d8a1bf8817141a
# Successfully built chainercv
# ...

# %%
# オブジェクト検出用の画像をアップロード
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-3c8a2a3a-8c8b-4bb9-91b2-dd6f57d7b705" name="files[]" multiple disabled />
#      <output id="result-3c8a2a3a-8c8b-4bb9-91b2-dd6f57d7b705">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dog.png to dog.png

# %%
# 画像の確認
from IPython.display import Image
Image('dog.png')

# %%
# オブジェクト検出
import matplotlib.pyplot as plt

from chainercv.datasets import voc_bbox_label_names
from chainercv.links import SSD300
from chainercv.utils import read_image
from chainercv.visualizations import vis_bbox

# Read an RGB image and return it in CHW format.
img = read_image('dog.png')
model = SSD300(pretrained_model='voc0712')
bboxes, labels, scores = model.predict([img])
vis_bbox(img, bboxes[0], labels[0], scores[0],
         label_names=voc_bbox_label_names)
plt.show()
# Out:
# ...
# From: https://chainercv-models.preferred.jp/ssd300_voc0712_converted_2017_06_06.npz
# To: /root/.chainer/dataset/_dl_cache/7580b6888d3f7742a1b531234009c0b0
#   %   Total    Recv       Speed  Time left
# 100   93MiB   93MiB   5371KiB/s    0:00:00
